# %% [markdown]
# ## Student Performance Linear Regression Project
#
# Today, I’m working on a project using **Linear Regression** with the **Student Performance** dataset from Kaggle.
# My goal is to analyze the factors that influence students’ academic performance and build a model that predicts the **Performance Index** based on variables such as:
#
# - **Study Hours**
# - **Previous Scores**
# - **Extracurricular Activities**
# - **Sleep Hours**
# - **Sample Question Papers Practiced**
#
# To ensure a clean and efficient workflow, I am also using **scikit-learn Pipelines**.
# With pipelines, I can streamline preprocessing steps—such as encoding categorical features, scaling numeric variables, and feeding the processed data directly into the regression model—making the entire process more organized, reproducible, and easier to maintain.
#
# This project aims to explore the relationships between these features and develop a regression pipeline that provides meaningful insights into student performance.

# %%
import pandas as pd 
import numpy as np 
import matlotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
